# %%
import torch
from typing import Optional, Dict
from dataclasses import dataclass
import random
import matplotlib.pyplot as plt
from stable_baselines3 import PPO
from IPython.display import clear_output
import matplotlib.colors as mcolors

import gymnasium as gym
import torch
import numpy as np
from collections import defaultdict
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.logger import Figure
tensorboard_log = './ppotb'
device='cpu'
inbred_parent_data = np.load('../nbs/data/g2f_ch10.npy', allow_pickle=True)

# %%
def set_seed(seed: int):
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    np.random.seed(seed)
    random.seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

@dataclass
class SimulationConfig:
    n_markers: int = 1000
    starting_parents: int = 20
    pop_size: int = 1000
    h2: float = 1.0
    sparse_reward: bool = True
    seed: int = 42

class Genome:
    def __init__(self, n_markers: int):
        self.ploidy: int = 2
        self.n_markers: int = n_markers

    def __repr__(self) -> str:
        return f"Genome(ploidy={self.ploidy}, n_markers={self.n_markers})"

class Population:
    def __init__(self, pop_size: int, haplotypes:torch.tensor, genome: Genome, device: torch.device):
        self.pop_size: int = pop_size
        self.genome: Genome = genome
        self.haplotypes: torch.Tensor = haplotypes
        self.device: torch.device = device
        



    def to(self, device: torch.device) -> 'Population':
        self.device = device
        self.haplotypes = self.haplotypes.to(device)
        return self

    def __repr__(self) -> str:
        return f"Population(pop_size={self.pop_size}, genome={self.genome}, device={self.device})"




class Trait:
    def __init__(self, genome: Genome, population: Population, target_mean: float = 0.0, target_variance: float = 1.0):
        self.genome: Genome = genome
        self.device: torch.device = population.device
        self.target_mean: float = target_mean
        self.target_variance: float = target_variance

        # Use torch.randn with a generator for reproducibility
        generator = torch.Generator(device=self.device)
        generator.manual_seed(torch.initial_seed())  # Use the seed set by torch.manual_seed()
        raw_effects = torch.randn(genome.n_markers, device=self.device, generator=generator)

        centered_effects = raw_effects - raw_effects.mean()
        dosages = population.haplotypes.sum(dim=1)
        founder_values = torch.einsum('ij,j->i', dosages, centered_effects)
        founder_mean = founder_values.mean()
        founder_var = founder_values.var()

        scaling_factor = torch.sqrt(self.target_variance / founder_var)
        self.effects: torch.Tensor = centered_effects * scaling_factor
        self.intercept: torch.Tensor = (torch.tensor(self.target_mean, device=self.device) - founder_mean).detach()
    def to(self, device: torch.device) -> 'Trait':
        self.device = device
        self.effects = self.effects.to(device)
        self.intercept = self.intercept.to(device)
        return self

    def __repr__(self) -> str:
        return f"Trait(target_mean={self.target_mean}, target_variance={self.target_variance}, device={self.device})"

class SimOps:
    @staticmethod
    def score_population(population: Population, trait: Trait, h2: float = 1.0) -> torch.Tensor:
        dosages = population.haplotypes.sum(dim=1)
        breeding_values = torch.einsum('ij,j->i', dosages, trait.effects)

        bv_var = breeding_values.var()
        if bv_var == 0 or h2 >= 1:
            return breeding_values

        env_variance = (1 - h2) / h2 * bv_var.item()
        env_std = torch.sqrt(torch.tensor(env_variance, device=population.device))
        env_effects = torch.randn_like(breeding_values) * env_std
        return breeding_values + env_effects + trait.intercept


    @staticmethod
    def truncation_selection(population: Population, phenotypes: torch.Tensor, selection_intensity: float, return_indices: bool = False) -> torch.Tensor:
        assert 0 < selection_intensity <= 1, "Selection intensity must be between 0 and 1"
        assert population.haplotypes.shape[0] == phenotypes.shape[0], "Mismatch between population size and phenotypes"

        num_select = max(1, min(int(selection_intensity * phenotypes.shape[0]), phenotypes.shape[0] - 1))
        print(f'DEBUG: num_select: {num_select}, population size: {phenotypes.shape[0]}')

        _, top_indices = torch.topk(phenotypes, num_select)
        if return_indices:
            return top_indices
        return population.haplotypes[top_indices]



    @staticmethod
    def meiosis(selected_haplotypes: torch.Tensor, num_crossovers: int = 1, num_gametes_per_parent: int = 1) -> torch.Tensor:
        num_parents, ploidy, num_markers = selected_haplotypes.shape

        # Repeat each parent's haplotypes num_gametes_per_parent times
        expanded_haplotypes = selected_haplotypes.repeat_interleave(num_gametes_per_parent, dim=0)

        # The rest of the function remains largely the same, but operates on the expanded haplotypes
        total_gametes = num_parents * num_gametes_per_parent

        crossover_points = torch.randint(1, num_markers, (total_gametes, num_crossovers), device=selected_haplotypes.device, generator=torch.Generator(device=selected_haplotypes.device).manual_seed(torch.initial_seed()))
        crossover_points, _ = torch.sort(crossover_points, dim=1)

        crossover_mask = torch.zeros((total_gametes, num_markers), dtype=torch.bool, device=selected_haplotypes.device)
        crossover_mask.scatter_(1, crossover_points, 1)
        crossover_mask = torch.cumsum(crossover_mask, dim=1) % 2 == 1

        crossover_mask = crossover_mask.unsqueeze(1).expand(-1, ploidy, -1)

        start_chromosome = torch.randint(0, ploidy, (total_gametes, 1), device=selected_haplotypes.device)
        start_mask = start_chromosome.unsqueeze(-1).expand(-1, -1, num_markers)

        final_mask = crossover_mask ^ start_mask.bool()

        offspring_haplotypes = torch.where(final_mask, expanded_haplotypes, expanded_haplotypes.roll(shifts=1, dims=1))

        # Return only the first haplotype for each meiosis event
        return offspring_haplotypes[:, 0, :]
    @staticmethod
    def check_cuda(tensor: torch.Tensor, name: str) -> None:
        print(f"{name} is on: {tensor.device}")


    @staticmethod
    def random_cross(gamete_tensor: torch.Tensor, total_crosses: int) -> torch.Tensor:
        num_gametes, n_markers = gamete_tensor.shape

        # Double the gamete tensor until we have enough for the total crosses
        while num_gametes < 2 * total_crosses:
            gamete_tensor = torch.cat([gamete_tensor, gamete_tensor], dim=0)
            num_gametes *= 2

        # Randomly select gametes for crossing
        gamete_indices = torch.randperm(num_gametes, device=gamete_tensor.device)
        parent1_indices = gamete_indices[:total_crosses]
        parent2_indices = gamete_indices[total_crosses:2*total_crosses]

        # Create the new population haplotype tensor
        new_population = torch.stack([
            gamete_tensor[parent1_indices],
            gamete_tensor[parent2_indices]
        ], dim=1)

        return new_population
    
def grab_inbred_parents(starting_parents, genome, seed, device=device):
    np.random.seed(seed)
    torch.manual_seed(seed)
    inbred_data = inbred_parent_data
    if starting_parents > inbred_data.shape[0]:
        raise ValueError("Total parents requested exceed the number of available parents.")
    if genome.n_markers > inbred_data.shape[2]:
        raise ValueError("Total markers requested exceed the number of available markers.")
    
    # Randomly sample parents
    sampled_parents_indices = np.random.choice(inbred_data.shape[0], starting_parents, replace=False)
    sampled_parents = inbred_data[sampled_parents_indices, :, :]
    
    # Randomly sample markers
    sampled_markers_indices = np.random.choice(inbred_data.shape[2], genome.n_markers, replace=False)
    
    return torch.tensor(sampled_parents[:, :, sampled_markers_indices], device=device).float()

##################

class SimParams:
    def __init__(self, config: SimulationConfig):
        self.config = config
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
        # Set the seed
        torch.manual_seed(config.seed)
        np.random.seed(config.seed)
        random.seed(config.seed)
        
        self.genome = Genome(config.n_markers)
        self.population = Population(config.pop_size, grab_inbred_parents(5, self.genome, config.seed), self.genome, device)
        
        f1 = self.perform_meiosis(self.population.haplotypes, num_crossovers=3, num_gametes_per_parent=((2000//self.population.haplotypes.shape[0]) *self.population.haplotypes.shape[0] + 100))
        self.create_next_generation(f1, total_crosses=2000)
        
        num_gametes_per_parent = (self.population.haplotypes.shape[0] / config.pop_size) + 2 
        segregating_pop = self.perform_meiosis(self.population.haplotypes, num_crossovers=3, num_gametes_per_parent=100)
        self.create_next_generation(segregating_pop, total_crosses=config.pop_size)
        
        self.trait = Trait(self.genome, self.population)
        
        # Calculate initial statistics for normalization
        initial_phenotypes = self.score_population()
        self.initial_max_phenotype = initial_phenotypes.max().item()
        self.initial_phenotype_std = initial_phenotypes.std().item()

    def normalize_reward(self, reward: float) -> float:
        """Normalize the reward based on initial population statistics."""
        normalized_reward = (reward - self.initial_max_phenotype) / self.initial_phenotype_std
        return normalized_reward
    
    def score_population(self, h2: Optional[float] = None) -> torch.Tensor:
        h2 = h2 if h2 is not None else self.config.h2
        return SimOps.score_population(self.population, self.trait, h2)

    def truncation_selection(self, selection_intensity: Optional[float] = None, phenotypes: Optional[torch.Tensor] = None, return_indices: bool = False) -> torch.Tensor:
        selection_intensity = selection_intensity if selection_intensity is not None else self.config.selection_intensity
        if phenotypes is None:
            phenotypes = self.score_population()
        return SimOps.truncation_selection(self.population, phenotypes, selection_intensity, return_indices)

    def check_device(self) -> None:
        SimOps.check_cuda(self.population.haplotypes, "Population haplotypes")
        SimOps.check_cuda(self.trait.effects, "Trait effects")
        SimOps.check_cuda(self.trait.intercept, "Trait intercept")

    def to(self, device: torch.device) -> 'SimParams':
        self.device = device
        self.population = self.population.to(device)
        self.trait = self.trait.to(device)
        return self
    def perform_meiosis(self, selected_haplotypes: torch.Tensor, num_crossovers: int = 1, num_gametes_per_parent: int = 1) -> torch.Tensor:
        return SimOps.meiosis(selected_haplotypes, num_crossovers, num_gametes_per_parent)

    def create_next_generation(self, gametes: torch.Tensor, total_crosses: int) -> None:
        new_population_haplotypes = SimOps.random_cross(gametes, total_crosses)
        # assert new_population_haplotypes.shape[0] == self.config.pop_size, "Population size changed unexpectedly"
        self.population.haplotypes = new_population_haplotypes
        self.population.pop_size = total_crosses


import numpy as np
from stable_baselines3.common.callbacks import BaseCallback
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
from IPython.display import clear_output

import numpy as np
import gymnasium as gym
import torch

import numpy as np
import gymnasium as gym
import torch


    
    
    
from collections import defaultdict
import numpy as np
import matplotlib.pyplot as plt
from stable_baselines3.common.callbacks import BaseCallback
from IPython.display import clear_output




class GeneralizedVisualizationCallback(BaseCallback):
    def __init__(self, verbose=0, log_freq=2000, baseline_value=None, best_action=None, baseline_results=None):
        super().__init__(verbose)
        self.data = defaultdict(lambda: defaultdict(list))
        self.log_freq = log_freq
        self.excluded_metrics = ['TimeLimit.truncated', 'current_generation']
        self.baseline_value = baseline_value
        self.best_action = best_action
        self.baseline_results = baseline_results
        
    def _on_step(self) -> bool:
        info = self.locals['infos'][0]
        obs = self.locals['new_obs']
        
        current_generation = info['current_generation']
        
        # Track all scalar values from the observation space
        for key, value in obs.items():
            if np.isscalar(value) and key not in self.excluded_metrics:
                self.data[key][current_generation].append(value)
        
        # Also track any scalar values from the info dict
        for key, value in info.items():
            if np.isscalar(value) and key not in self.excluded_metrics:
                self.data[key][current_generation].append(value)

        if self.num_timesteps % self.log_freq == 0:
            self.visualize()

        return True
    
    def action_to_selection_intensity(self,action):
        return (action + 1) / 2 * 0.98 + 0.01

    def visualize(self, window_size=100):
        num_metrics = len(self.data)
        fig, axes = plt.subplots(num_metrics, 1, figsize=(12, 6*num_metrics), sharex=True)
        if num_metrics == 1:
            axes = [axes]

        for idx, (metric, generations) in enumerate(self.data.items()):
            ax = axes[idx]
            num_generations = len(generations)
            blue_cmap = plt.cm.Blues
            red_cmap = plt.cm.Reds
            blue_colors = blue_cmap(np.linspace(0.3, 1, num_generations))
            red_colors = red_cmap(np.linspace(0.3, 1, num_generations))

            for i, (generation, values) in enumerate(generations.items()):
                steps = np.arange(len(values))
                if metric == 'selection_intensity':
                    values = [self.action_to_selection_intensity(v) for v in values]

                # Calculate rolling moving average with specified window size
                rolling_avg = np.convolve(values, np.ones(window_size), 'valid') / window_size
                rolling_steps = steps[window_size-1:]

                ax.plot(rolling_steps, rolling_avg, label=f'Agent {generation}', color=blue_colors[i])
                ax.set_title(f'{metric.capitalize()} per Generation')
                ax.set_ylabel(f'Rolling Avg {metric.capitalize()}')
                ax.grid(True)

            # Add baseline results for max_phenotype and genetic_variance with gradient
            if self.baseline_results is not None:
                if metric == 'max_phenotype':
                    baseline_data = self.baseline_results[0]
                    for gen, value in enumerate(baseline_data):
                        ax.axhline(y=value, color=red_colors[gen], linestyle='--', alpha=0.7, label=f'Baseline {gen+1}')
                elif metric == 'genetic_variance':
                    baseline_data = self.baseline_results[1]
                    for gen, value in enumerate(baseline_data):
                        ax.axhline(y=value, color=red_colors[gen], linestyle='--', alpha=0.7, label=f'Baseline {gen+1}')

            # Add best_action line for selection_intensity chart
            if metric == 'selection_intensity' and self.best_action is not None:
                best_action_intensity = self.action_to_selection_intensity(self.best_action)
                ax.axhline(y=best_action_intensity, color='r', linestyle='--', label='Best Constant Action')

            # Set y-axis limits for selection_intensity
            if metric == 'selection_intensity':
                ax.set_ylim(0, 1)

            # Create a custom legend
            handles, labels = ax.get_legend_handles_labels()
            by_label = dict(zip(labels, handles))
            ax.legend(by_label.values(), by_label.keys(), bbox_to_anchor=(-0.1, 1), loc='upper right', fontsize='small')

        axes[-1].set_xlabel('Steps within Generation')
        plt.tight_layout()
        plt.subplots_adjust(left=0.3)  # Adjust this value as needed
        clear_output(wait=True)
        plt.show()
        

def get_constant_action_baseline(env, num_reps=30):
    action_grid = np.linspace(-.99, -.3, 30)
    best_action = None
    best_mean_max_phenotype = float('-inf')
    best_results = None

    max_generations = env.max_generations

    for action in action_grid:
        all_max_phenotypes = np.zeros((num_reps, max_generations))
        all_genetic_variances = np.zeros((num_reps, max_generations))

        for rep in range(num_reps):
            obs, _ = env.reset()
            done = False
            gen = 0
            while not done:
                obs, reward, done, _, info = env.step([action])
                all_max_phenotypes[rep, gen] = info['max_phenotype']
                all_genetic_variances[rep, gen] = info['genetic_variance']
                gen += 1

        mean_max_phenotypes = np.mean(all_max_phenotypes, axis=0)
        mean_genetic_variances = np.mean(all_genetic_variances, axis=0)
        
        final_mean_max_phenotype = mean_max_phenotypes[-1]

        if final_mean_max_phenotype > best_mean_max_phenotype:
            best_mean_max_phenotype = final_mean_max_phenotype
            best_action = action
            best_results = np.vstack((mean_max_phenotypes, mean_genetic_variances))

    return best_action, best_mean_max_phenotype, best_results


### 

class SelectionIntensityEnvironment(gym.Env):
    def __init__(self, SP, config, max_generations=10):
        super(SelectionIntensityEnvironment, self).__init__()
        self.SP = SP
        self.config = config
        self.max_generations = max_generations
        self.current_generation = 0
        self.founder_population = self.SP.population.haplotypes
        self.action_space = gym.spaces.Box(low=-1, high=1, shape=(1,), dtype=np.float32)
        self.observation_space = gym.spaces.Dict({
            "generation_percent_remaining": gym.spaces.Box(low=0, high=1, shape=(1,), dtype=np.float32),
            "genetic_var": gym.spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
            "average_episode_actions": gym.spaces.Box(low=0, high=1, shape=(1,), dtype=np.float32),
        })
        self.current_population = self.SP.population.haplotypes.clone()
        self.phenotypes = self.SP.score_population()
        self.action_history = []
        self.last_selected_phenotypes = None
        

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_generation = 0
        self.SP.population.haplotypes = self.founder_population.clone()
        self.phenotypes = self.SP.score_population()
        self.action_history = []
        self.last_selected_phenotypes = None
        return self._get_observation(), {}

    def _get_observation(self):
        return {
            "generation_percent_remaining": np.array([(self.max_generations - self.current_generation) / self.max_generations], dtype=np.float32),
            "genetic_var": np.array([self.phenotypes.var().item()], dtype=np.float32),
            "average_episode_actions": np.array([np.mean(self.action_history) if self.action_history else 0], dtype=np.float32),
        }


    def step(self, action):
        # Rescale action from [-1, 1] to [0.01, 0.99]
        selection_intensity = (action[0] + 1) / 2 * 0.98 + 0.01
        self.action_history.append(selection_intensity)


        # Select parents
        selected_indices = self.SP.truncation_selection(selection_intensity, self.phenotypes, return_indices=True)
        self.last_selected_phenotypes = self.phenotypes[selected_indices]
        selected_haplotypes = self.SP.population.haplotypes[selected_indices]

        # Create next generation
        total_crosses = self.config.pop_size
        total_gametes_needed = total_crosses * 2
        num_parents = selected_haplotypes.shape[0]
        num_gametes_per_parent = -(-total_gametes_needed // num_parents) + 2
        gametes = self.SP.perform_meiosis(selected_haplotypes, num_crossovers=3, num_gametes_per_parent=num_gametes_per_parent)
        self.SP.create_next_generation(gametes, total_crosses)

        # Update phenotypes and other variables for the new generation
        self.phenotypes = self.SP.score_population()
        self.current_generation += 1

        done = self.current_generation >= self.max_generations

        if self.config.sparse_reward:
            raw_reward = float(self.phenotypes.max().item()) if done else 0.0
        else:
            raw_reward = float(self.phenotypes.max().item())
        reward = self.SP.normalize_reward(raw_reward)

        observation = self._get_observation()
        info = {
            'max_phenotype': float(self.phenotypes.max().item()),
            'genetic_variance': float(self.phenotypes.var().item()),
            'selection_intensity': float(action[0]),
            'current_generation': self.current_generation,
        }

        return observation, reward, done, False, info
    
    
    
# max_generations= 10
# total_timesteps = max_generations*5000
# config = SimulationConfig(n_markers=100, starting_parents=200,pop_size=100,sparse_reward=False,seed=22)
# SP = SimParams(config)
# env = SelectionIntensityEnvironment(SP, config, max_generations=max_generations)

# %%
@dataclass
class SimulationConfig:
    n_markers: int = 1000
    starting_parents: int = 20
    pop_size: int = 1000
    h2: float = 1.0
    max_generations:int = 10
    sparse_reward: bool = True
    seed: int = 42
    starting_budget: int = 1000
        
import gymnasium as gym
import numpy as np
import torch

class BudgetEnvironment(gym.Env):
    def __init__(self, SP, config):
        super(BudgetEnvironment, self).__init__()
        
        self.SP = SP
        self.config = config
        self.starting_budget = config.starting_budget
        self.remaining_budget = self.starting_budget
        self.device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        
        self.max_generations = config.max_generations
        self.current_generation = 0
        self.founder_population = self.SP.population.haplotypes.clone()
        
        # Define action space: [selection_intensity, budget_to_spend]
        self.action_space = gym.spaces.Box(
            low=np.array([-1, 0]), 
            high=np.array([1, 1]), 
            shape=(2,), 
            dtype=np.float32
        )
        
        # Define observation space
        self.observation_space = gym.spaces.Dict({
            "generation_percent_remaining": gym.spaces.Box(low=0, high=1, shape=(1,), dtype=np.float32),
            "genetic_var": gym.spaces.Box(low=0, high=np.inf, shape=(1,), dtype=np.float32),
            "average_episode_actions": gym.spaces.Box(low=0, high=1, shape=(2,), dtype=np.float32),
            "remaining_budget_percent": gym.spaces.Box(low=0, high=1, shape=(1,), dtype=np.float32),
        })
        
        self.current_population = self.SP.population.haplotypes.clone()
        self.phenotypes = self.SP.score_population()
        self.action_history = []
        self.last_selected_phenotypes = None
        
        
        
    def _get_observation(self):
        return {
    "generation_percent_remaining": np.array([(self.max_generations - self.current_generation) / self.max_generations], dtype=np.float32),
    "genetic_var": np.array([self.phenotypes.var().item()], dtype=np.float32),
    "average_episode_actions": np.array([
        np.mean([action[0] for action in self.action_history]) if self.action_history else 0,
        np.mean([action[1] for action in self.action_history]) if self.action_history else 0
    ], dtype=np.float32),
    "remaining_budget_percent": np.array([self.remaining_budget / self.starting_budget], dtype=np.float32)
}
        
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.current_generation = 0
        self.SP.population.haplotypes = self.founder_population.clone()
        self.phenotypes = self.SP.score_population()
        self.action_history = []
        self.last_selected_phenotypes = None

        # Reset the budget
        self.remaining_budget = self.starting_budget

        return self._get_observation(), {}
    def step(self, action):
        # Unpack the action
        selection_intensity, budget_to_spend = action

        # Rescale selection_intensity from [-1, 1] to [0.01, 0.99]
        selection_intensity = (selection_intensity + 1) / 2 * 0.98 + 0.01

        # Ensure budget_to_spend is between 0 and 1
        budget_to_spend = max(0, min(budget_to_spend, 1))

        print(f"DEBUG: Action received - Selection Intensity: {selection_intensity:.4f}, Budget to Spend: {budget_to_spend:.4f}")
        print(f"DEBUG: Current remaining budget: {self.remaining_budget:.2f}")

        # Calculate the actual budget to spend
        actual_budget_spent = self.remaining_budget * budget_to_spend
        self.remaining_budget -= actual_budget_spent

        print(f"DEBUG: Actual budget spent: {actual_budget_spent:.2f}")
        print(f"DEBUG: Updated remaining budget: {self.remaining_budget:.2f}")

        # Calculate the number of additional offspring based on budget spent
        base_offspring = self.config.pop_size
        additional_offspring = int(actual_budget_spent / 10)  # Assuming 10 budget units per additional offspring
        total_offspring = base_offspring + additional_offspring

        print(f"DEBUG: Base offspring: {base_offspring}, Additional offspring: {additional_offspring}")
        print(f"DEBUG: Total offspring to produce: {total_offspring}")

        self.action_history.append((selection_intensity, budget_to_spend))

        # Select parents
        num_select = max(1, min(int(selection_intensity * self.config.pop_size), self.config.pop_size - 1))
        selected_indices = self.SP.truncation_selection(selection_intensity, self.phenotypes, return_indices=True)
        selected_indices = selected_indices[:num_select]  # Ensure we don't select more than num_select
        self.last_selected_phenotypes = self.phenotypes[selected_indices]
        selected_haplotypes = self.SP.population.haplotypes[selected_indices]

        print(f"DEBUG: Number of selected parents: {len(selected_indices)}")

        # Create next generation
        num_parents = selected_haplotypes.shape[0]
        num_gametes_per_parent = max(2, -(-total_offspring * 2 // num_parents))

        print(f"DEBUG: Gametes per parent: {num_gametes_per_parent}")

        gametes = self.SP.perform_meiosis(selected_haplotypes, num_crossovers=3, num_gametes_per_parent=num_gametes_per_parent)
        self.SP.create_next_generation(gametes, total_offspring)

        # Score the new population
        new_phenotypes = self.SP.score_population()

        print(f"DEBUG: New population size: {len(new_phenotypes)}")

        # Keep only the top scoring individuals to maintain the original population size
        _, top_indices = torch.topk(new_phenotypes, self.config.pop_size)
        self.SP.population.haplotypes = self.SP.population.haplotypes[top_indices]
        self.phenotypes = new_phenotypes[top_indices]

        print(f"DEBUG: Final population size after selection: {len(self.phenotypes)}")

        self.current_generation += 1
        done = self.current_generation >= self.max_generations

        if self.config.sparse_reward:
            raw_reward = float(self.phenotypes.max().item()) if done else 0.0
        else:
            raw_reward = float(self.phenotypes.max().item())

        reward = self.SP.normalize_reward(raw_reward)

        print(f"DEBUG: Reward: {reward:.4f}")

        observation = self._get_observation()

        info = {
            'max_phenotype': float(self.phenotypes.max().item()),
            'genetic_variance': float(self.phenotypes.var().item()),
            'selection_intensity': float(selection_intensity),
            'budget_spent': float(actual_budget_spent),
            'remaining_budget': float(self.remaining_budget),
            'current_generation': self.current_generation,
        }

        return observation, reward, done, False, info





        
config = SimulationConfig(n_markers=120, max_generations=10, starting_parents=130,pop_size=100,sparse_reward=False,seed=22)
SP = SimParams(config)
env = BudgetEnvironment(SP,config)
env.reset()
env.step([.3,.3])
# Out:
# DEBUG: Action received - Selection Intensity: 0.6470, Budget to Spend: 0.3000
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 300.00
# DEBUG: Updated remaining budget: 700.00
# DEBUG: Base offspring: 100, Additional offspring: 30
# DEBUG: Total offspring to produce: 130
# DEBUG: num_select: 64, population size: 100
# DEBUG: Number of selected parents: 64
# DEBUG: Gametes per parent: 5
# DEBUG: New population size: 130
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 0.4415
# ({'generation_percent_remaining': array([0.9], dtype=float32),
#   'genetic_var': array([0.7235559], dtype=float32),
#   'average_episode_actions': array([0.647, 0.3  ], dtype=float32),
#   'remaining_budget_percent': array([0.7], dtype=float32)},
#  0.44149065017700195,
#  False,
#  False,
#  {'max_phenotype': 3.166811466217041,
#   'genetic_variance': 0.7235559225082397,
#   'selection_intensity': 0.647,
#   'budget_spent': 300.0,
#   'remaining_budget': 700.0,
#   'current_generation': 1})

# %%
env.step([.3,.3])
# Out:
# DEBUG: Action received - Selection Intensity: 0.6470, Budget to Spend: 0.3000
# DEBUG: Current remaining budget: 700.00
# DEBUG: Actual budget spent: 210.00
# DEBUG: Updated remaining budget: 490.00
# DEBUG: Base offspring: 100, Additional offspring: 21
# DEBUG: Total offspring to produce: 121
# DEBUG: num_select: 64, population size: 100
# DEBUG: Number of selected parents: 64
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 121
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.2745
# ({'generation_percent_remaining': array([0.8], dtype=float32),
#   'genetic_var': array([0.6488256], dtype=float32),
#   'average_episode_actions': array([0.647, 0.3  ], dtype=float32),
#   'remaining_budget_percent': array([0.49], dtype=float32)},
#  1.2744910717010498,
#  False,
#  False,
#  {'max_phenotype': 3.999811887741089,
#   'genetic_variance': 0.6488255858421326,
#   'selection_intensity': 0.647,
#   'budget_spent': 210.0,
#   'remaining_budget': 490.0,
#   'current_generation': 2})

# %%
total_timesteps=10000
model = PPO("MultiInputPolicy", env, device='cuda', verbose=1, tensorboard_log=tensorboard_log)
vis_callback = GeneralizedVisualizationCallback(log_freq=1000)
# Train the model
model.learn(total_timesteps=total_timesteps, callback=vis_callback)
# Out:
# DEBUG: Action received - Selection Intensity: 0.7431, Budget to Spend: 0.2370
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 237.01
# DEBUG: Updated remaining budget: 762.99
# DEBUG: Base offspring: 100, Additional offspring: 23
# DEBUG: Total offspring to produce: 123
# DEBUG: num_select: 74, population size: 100
# DEBUG: Number of selected parents: 74
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 123
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 0.6134
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 762.99
# DEBUG: Actual budget spent: 762.99
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 76
# DEBUG: Total offspring to produce: 176
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 352
# DEBUG: New population size: 176
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.9514
# DEBUG: Action received - Selection Intensity: 0.8774, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 87, population size: 100
# DEBUG: Number of selected parents: 87
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.1731
# DEBUG: Action received - Selection Intensity: 0.7361, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 73, population size: 100
# DEBUG: Number of selected parents: 73
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.3006
# DEBUG: Action received - Selection Intensity: 0.3688, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 36, population size: 100
# DEBUG: Number of selected parents: 36
# DEBUG: Gametes per parent: 6
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.4157
# DEBUG: Action received - Selection Intensity: 0.6954, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 69, population size: 100
# DEBUG: Number of selected parents: 69
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.5555
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.7195
# DEBUG: Action received - Selection Intensity: 0.1544, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 15, population size: 100
# DEBUG: Number of selected parents: 15
# DEBUG: Gametes per parent: 14
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.8323
# DEBUG: Action received - Selection Intensity: 0.2074, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 20, population size: 100
# DEBUG: Number of selected parents: 20
# DEBUG: Gametes per parent: 10
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.9451
# DEBUG: Action received - Selection Intensity: 0.3978, Budget to Spend: 0.5208
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 39, population size: 100
# DEBUG: Number of selected parents: 39
# DEBUG: Gametes per parent: 6
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.8723
# DEBUG: Action received - Selection Intensity: 0.3432, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 1000.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 34, population size: 100
# DEBUG: Number of selected parents: 34
# DEBUG: Gametes per parent: 6
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 0.8887
# DEBUG: Action received - Selection Intensity: 0.6224, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 1000.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 62, population size: 100
# DEBUG: Number of selected parents: 62
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.7758
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 1000.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.7755
# DEBUG: Action received - Selection Intensity: 0.9275, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 1000.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 92, population size: 100
# DEBUG: Number of selected parents: 92
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.7525
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.2598
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 259.84
# DEBUG: Updated remaining budget: 740.16
# DEBUG: Base offspring: 100, Additional offspring: 25
# DEBUG: Total offspring to produce: 125
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 250
# DEBUG: New population size: 125
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.2566
# DEBUG: Action received - Selection Intensity: 0.3464, Budget to Spend: 0.2913
# DEBUG: Current remaining budget: 740.16
# DEBUG: Actual budget spent: 215.60
# DEBUG: Updated remaining budget: 524.56
# DEBUG: Base offspring: 100, Additional offspring: 21
# DEBUG: Total offspring to produce: 121
# DEBUG: num_select: 34, population size: 100
# DEBUG: Number of selected parents: 34
# DEBUG: Gametes per parent: 8
# DEBUG: New population size: 121
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.3112
# DEBUG: Action received - Selection Intensity: 0.4373, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 524.56
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 524.56
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 43, population size: 100
# DEBUG: Number of selected parents: 43
# DEBUG: Gametes per parent: 5
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.3363
# DEBUG: Action received - Selection Intensity: 0.3197, Budget to Spend: 0.4870
# DEBUG: Current remaining budget: 524.56
# DEBUG: Actual budget spent: 255.44
# DEBUG: Updated remaining budget: 269.13
# DEBUG: Base offspring: 100, Additional offspring: 25
# DEBUG: Total offspring to produce: 125
# DEBUG: num_select: 31, population size: 100
# DEBUG: Number of selected parents: 31
# DEBUG: Gametes per parent: 9
# DEBUG: New population size: 125
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.4696
# DEBUG: Action received - Selection Intensity: 0.3353, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 269.13
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 269.13
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 33, population size: 100
# DEBUG: Number of selected parents: 33
# DEBUG: Gametes per parent: 7
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.4980
# DEBUG: Action received - Selection Intensity: 0.9900, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 269.13
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 269.13
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 99, population size: 100
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.5767
# DEBUG: Action received - Selection Intensity: 0.8745, Budget to Spend: 0.2596
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 259.60
# DEBUG: Updated remaining budget: 740.40
# DEBUG: Base offspring: 100, Additional offspring: 25
# DEBUG: Total offspring to produce: 125
# DEBUG: num_select: 87, population size: 100
# DEBUG: Number of selected parents: 87
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 125
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.0830
# DEBUG: Action received - Selection Intensity: 0.0868, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 740.40
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 740.40
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 8, population size: 100
# DEBUG: Number of selected parents: 8
# DEBUG: Gametes per parent: 25
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.2914
# DEBUG: Action received - Selection Intensity: 0.1652, Budget to Spend: 0.1631
# DEBUG: Current remaining budget: 740.40
# DEBUG: Actual budget spent: 120.76
# DEBUG: Updated remaining budget: 619.64
# DEBUG: Base offspring: 100, Additional offspring: 12
# DEBUG: Total offspring to produce: 112
# DEBUG: num_select: 16, population size: 100
# DEBUG: Number of selected parents: 16
# DEBUG: Gametes per parent: 14
# DEBUG: New population size: 112
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.0754
# DEBUG: Action received - Selection Intensity: 0.2564, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 619.64
# DEBUG: Actual budget spent: 619.64
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 61
# DEBUG: Total offspring to produce: 161
# DEBUG: num_select: 25, population size: 100
# DEBUG: Number of selected parents: 25
# DEBUG: Gametes per parent: 13
# DEBUG: New population size: 161
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.7908
# DEBUG: Action received - Selection Intensity: 0.0212, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 2, population size: 100
# DEBUG: Number of selected parents: 2
# DEBUG: Gametes per parent: 100
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.5819
# DEBUG: Action received - Selection Intensity: 0.1322, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 13, population size: 100
# DEBUG: Number of selected parents: 13
# DEBUG: Gametes per parent: 16
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.9440
# DEBUG: Action received - Selection Intensity: 0.8473, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 84, population size: 100
# DEBUG: Number of selected parents: 84
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 5.7805
# DEBUG: Action received - Selection Intensity: 0.1566, Budget to Spend: 0.5872
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 15, population size: 100
# DEBUG: Number of selected parents: 15
# DEBUG: Gametes per parent: 14
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 6.0550
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.3669
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 6.0619
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 6.0619
# DEBUG: Action received - Selection Intensity: 0.1143, Budget to Spend: 0.9123
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 912.29
# DEBUG: Updated remaining budget: 87.71
# DEBUG: Base offspring: 100, Additional offspring: 91
# DEBUG: Total offspring to produce: 191
# DEBUG: num_select: 11, population size: 100
# DEBUG: Number of selected parents: 11
# DEBUG: Gametes per parent: 35
# DEBUG: New population size: 191
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.5671
# DEBUG: Action received - Selection Intensity: 0.9900, Budget to Spend: 0.9795
# DEBUG: Current remaining budget: 87.71
# DEBUG: Actual budget spent: 85.91
# DEBUG: Updated remaining budget: 1.80
# DEBUG: Base offspring: 100, Additional offspring: 8
# DEBUG: Total offspring to produce: 108
# DEBUG: num_select: 99, population size: 100
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 108
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.7306
# DEBUG: Action received - Selection Intensity: 0.6390, Budget to Spend: 0.8893
# DEBUG: Current remaining budget: 1.80
# DEBUG: Actual budget spent: 1.60
# DEBUG: Updated remaining budget: 0.20
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 63, population size: 100
# DEBUG: Number of selected parents: 63
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.7872
# DEBUG: Action received - Selection Intensity: 0.3510, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.20
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.20
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 35, population size: 100
# DEBUG: Number of selected parents: 35
# DEBUG: Gametes per parent: 6
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.4056
# DEBUG: Action received - Selection Intensity: 0.5937, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.20
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.20
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 59, population size: 100
# DEBUG: Number of selected parents: 59
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.4003
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.8106
# DEBUG: Current remaining budget: 0.20
# DEBUG: Actual budget spent: 0.16
# DEBUG: Updated remaining budget: 0.04
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.3127
# DEBUG: Action received - Selection Intensity: 0.0739, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.04
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.04
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 7, population size: 100
# DEBUG: Number of selected parents: 7
# DEBUG: Gametes per parent: 29
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.6132
# DEBUG: Action received - Selection Intensity: 0.1764, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.04
# DEBUG: Actual budget spent: 0.04
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 17, population size: 100
# DEBUG: Number of selected parents: 17
# DEBUG: Gametes per parent: 12
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.8632
# DEBUG: Action received - Selection Intensity: 0.4841, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 48, population size: 100
# DEBUG: Number of selected parents: 48
# DEBUG: Gametes per parent: 5
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 5.0610
# DEBUG: Action received - Selection Intensity: 0.5055, Budget to Spend: 0.9623
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 50, population size: 100
# DEBUG: Number of selected parents: 50
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 5.2359
# DEBUG: Action received - Selection Intensity: 0.7915, Budget to Spend: 0.1136
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 113.55
# DEBUG: Updated remaining budget: 886.45
# DEBUG: Base offspring: 100, Additional offspring: 11
# DEBUG: Total offspring to produce: 111
# DEBUG: num_select: 79, population size: 100
# DEBUG: Number of selected parents: 79
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 111
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.3927
# DEBUG: Action received - Selection Intensity: 0.7635, Budget to Spend: 0.5202
# DEBUG: Current remaining budget: 886.45
# DEBUG: Actual budget spent: 461.16
# DEBUG: Updated remaining budget: 425.29
# DEBUG: Base offspring: 100, Additional offspring: 46
# DEBUG: Total offspring to produce: 146
# DEBUG: num_select: 76, population size: 100
# DEBUG: Number of selected parents: 76
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 146
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.4000
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.3941
# DEBUG: Current remaining budget: 425.29
# DEBUG: Actual budget spent: 167.60
# DEBUG: Updated remaining budget: 257.68
# DEBUG: Base offspring: 100, Additional offspring: 16
# DEBUG: Total offspring to produce: 116
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 232
# DEBUG: New population size: 116
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.5246
# DEBUG: Action received - Selection Intensity: 0.9900, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 257.68
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 257.68
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 99, population size: 100
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.6384
# DEBUG: Action received - Selection Intensity: 0.6287, Budget to Spend: 0.4823
# DEBUG: Current remaining budget: 257.68
# DEBUG: Actual budget spent: 124.27
# DEBUG: Updated remaining budget: 133.41
# DEBUG: Base offspring: 100, Additional offspring: 12
# DEBUG: Total offspring to produce: 112
# DEBUG: num_select: 62, population size: 100
# DEBUG: Number of selected parents: 62
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 112
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.9950
# DEBUG: Action received - Selection Intensity: 0.2069, Budget to Spend: 0.6707
# DEBUG: Current remaining budget: 133.41
# DEBUG: Actual budget spent: 89.48
# DEBUG: Updated remaining budget: 43.93
# DEBUG: Base offspring: 100, Additional offspring: 8
# DEBUG: Total offspring to produce: 108
# DEBUG: num_select: 20, population size: 100
# DEBUG: Number of selected parents: 20
# DEBUG: Gametes per parent: 11
# DEBUG: New population size: 108
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.9587
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 43.93
# DEBUG: Actual budget spent: 43.93
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 4
# DEBUG: Total offspring to produce: 104
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 208
# DEBUG: New population size: 104
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.5232
# DEBUG: Action received - Selection Intensity: 0.9900, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 99, population size: 100
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.6580
# DEBUG: Action received - Selection Intensity: 0.4548, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 45, population size: 100
# DEBUG: Number of selected parents: 45
# DEBUG: Gametes per parent: 5
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.7586
# DEBUG: Action received - Selection Intensity: 0.1897, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 18, population size: 100
# DEBUG: Number of selected parents: 18
# DEBUG: Gametes per parent: 12
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 5.0205
# DEBUG: Action received - Selection Intensity: 0.4720, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 1000.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 47, population size: 100
# DEBUG: Number of selected parents: 47
# DEBUG: Gametes per parent: 5
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 0.9517
# DEBUG: Action received - Selection Intensity: 0.4726, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 1000.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 47, population size: 100
# DEBUG: Number of selected parents: 47
# DEBUG: Gametes per parent: 5
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.7966
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 1000.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 100
# DEBUG: Total offspring to produce: 200
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 400
# DEBUG: New population size: 200
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.9500
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.6351
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.0426
# DEBUG: Action received - Selection Intensity: 0.5091, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 50, population size: 100
# DEBUG: Number of selected parents: 50
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.0426
# DEBUG: Action received - Selection Intensity: 0.6739, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 67, population size: 100
# DEBUG: Number of selected parents: 67
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.0426
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.7924
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.0427
# DEBUG: Action received - Selection Intensity: 0.1515, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 15, population size: 100
# DEBUG: Number of selected parents: 15
# DEBUG: Gametes per parent: 14
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.0427
# DEBUG: Action received - Selection Intensity: 0.9900, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 99, population size: 100
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.0427
# DEBUG: Action received - Selection Intensity: 0.1941, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 19, population size: 100
# DEBUG: Number of selected parents: 19
# DEBUG: Gametes per parent: 11
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.0427
# DEBUG: Action received - Selection Intensity: 0.0534, Budget to Spend: 0.6050
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 604.99
# DEBUG: Updated remaining budget: 395.01
# DEBUG: Base offspring: 100, Additional offspring: 60
# DEBUG: Total offspring to produce: 160
# DEBUG: num_select: 5, population size: 100
# DEBUG: Number of selected parents: 5
# DEBUG: Gametes per parent: 64
# DEBUG: New population size: 160
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.7962
# DEBUG: Action received - Selection Intensity: 0.2008, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 395.01
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 395.01
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 20, population size: 100
# DEBUG: Number of selected parents: 20
# DEBUG: Gametes per parent: 10
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.3616
# DEBUG: Action received - Selection Intensity: 0.9900, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 395.01
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 395.01
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 99, population size: 100
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.5409
# DEBUG: Action received - Selection Intensity: 0.5860, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 395.01
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 395.01
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 58, population size: 100
# DEBUG: Number of selected parents: 58
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.5625
# DEBUG: Action received - Selection Intensity: 0.3478, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 395.01
# DEBUG: Actual budget spent: 395.01
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 39
# DEBUG: Total offspring to produce: 139
# DEBUG: num_select: 34, population size: 100
# DEBUG: Number of selected parents: 34
# DEBUG: Gametes per parent: 9
# DEBUG: New population size: 139
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.4363
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.4619
# DEBUG: Action received - Selection Intensity: 0.3577, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 35, population size: 100
# DEBUG: Number of selected parents: 35
# DEBUG: Gametes per parent: 6
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.8590
# DEBUG: Action received - Selection Intensity: 0.8114, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 81, population size: 100
# DEBUG: Number of selected parents: 81
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 5.0317
# DEBUG: Action received - Selection Intensity: 0.0246, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 2, population size: 100
# DEBUG: Number of selected parents: 2
# DEBUG: Gametes per parent: 100
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 5.9906
# DEBUG: Action received - Selection Intensity: 0.2458, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 24, population size: 100
# DEBUG: Number of selected parents: 24
# DEBUG: Gametes per parent: 9
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 6.1901
# DEBUG: Action received - Selection Intensity: 0.0872, Budget to Spend: 0.5132
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 513.20
# DEBUG: Updated remaining budget: 486.80
# DEBUG: Base offspring: 100, Additional offspring: 51
# DEBUG: Total offspring to produce: 151
# DEBUG: num_select: 8, population size: 100
# DEBUG: Number of selected parents: 8
# DEBUG: Gametes per parent: 38
# DEBUG: New population size: 151
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.7827
# DEBUG: Action received - Selection Intensity: 0.3345, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 486.80
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 486.80
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 33, population size: 100
# DEBUG: Number of selected parents: 33
# DEBUG: Gametes per parent: 7
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.9688
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 486.80
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 486.80
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.5121
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.3711
# DEBUG: Current remaining budget: 486.80
# DEBUG: Actual budget spent: 180.64
# DEBUG: Updated remaining budget: 306.16
# DEBUG: Base offspring: 100, Additional offspring: 18
# DEBUG: Total offspring to produce: 118
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 236
# DEBUG: New population size: 118
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.1822
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 306.16
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 306.16
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.8162
# DEBUG: Action received - Selection Intensity: 0.1589, Budget to Spend: 0.0753
# DEBUG: Current remaining budget: 306.16
# DEBUG: Actual budget spent: 23.06
# DEBUG: Updated remaining budget: 283.10
# DEBUG: Base offspring: 100, Additional offspring: 2
# DEBUG: Total offspring to produce: 102
# DEBUG: num_select: 15, population size: 100
# DEBUG: Number of selected parents: 15
# DEBUG: Gametes per parent: 14
# DEBUG: New population size: 102
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.8162
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.6062
# DEBUG: Current remaining budget: 283.10
# DEBUG: Actual budget spent: 171.63
# DEBUG: Updated remaining budget: 111.47
# DEBUG: Base offspring: 100, Additional offspring: 17
# DEBUG: Total offspring to produce: 117
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 234
# DEBUG: New population size: 117
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.9538
# DEBUG: Action received - Selection Intensity: 0.1458, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 111.47
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 111.47
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 14, population size: 100
# DEBUG: Number of selected parents: 14
# DEBUG: Gametes per parent: 15
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.9538
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.0322
# DEBUG: Current remaining budget: 111.47
# DEBUG: Actual budget spent: 3.59
# DEBUG: Updated remaining budget: 107.88
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.9538
# DEBUG: Action received - Selection Intensity: 0.3025, Budget to Spend: 0.2209
# DEBUG: Current remaining budget: 107.88
# DEBUG: Actual budget spent: 23.83
# DEBUG: Updated remaining budget: 84.04
# DEBUG: Base offspring: 100, Additional offspring: 2
# DEBUG: Total offspring to produce: 102
# DEBUG: num_select: 30, population size: 100
# DEBUG: Number of selected parents: 30
# DEBUG: Gametes per parent: 7
# DEBUG: New population size: 102
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.9538
# DEBUG: Action received - Selection Intensity: 0.6101, Budget to Spend: 0.4422
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 442.19
# DEBUG: Updated remaining budget: 557.81
# DEBUG: Base offspring: 100, Additional offspring: 44
# DEBUG: Total offspring to produce: 144
# DEBUG: num_select: 61, population size: 100
# DEBUG: Number of selected parents: 61
# DEBUG: Gametes per parent: 5
# DEBUG: New population size: 144
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.1140
# DEBUG: Action received - Selection Intensity: 0.9900, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 557.81
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 557.81
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 99, population size: 100
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.0111
# DEBUG: Action received - Selection Intensity: 0.1537, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 557.81
# DEBUG: Actual budget spent: 557.81
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 55
# DEBUG: Total offspring to produce: 155
# DEBUG: num_select: 15, population size: 100
# DEBUG: Number of selected parents: 15
# DEBUG: Gametes per parent: 21
# DEBUG: New population size: 155
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.6652
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.2632
# DEBUG: Action received - Selection Intensity: 0.6424, Budget to Spend: 0.3634
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 64, population size: 100
# DEBUG: Number of selected parents: 64
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.6036
# DEBUG: Action received - Selection Intensity: 0.7049, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 70, population size: 100
# DEBUG: Number of selected parents: 70
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.7464
# DEBUG: Action received - Selection Intensity: 0.9900, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 99, population size: 100
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.2964
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.7673
# DEBUG: Action received - Selection Intensity: 0.1784, Budget to Spend: 0.9173
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 17, population size: 100
# DEBUG: Number of selected parents: 17
# DEBUG: Gametes per parent: 12
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.9249
# DEBUG: Action received - Selection Intensity: 0.5942, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 59, population size: 100
# DEBUG: Number of selected parents: 59
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 5.0489
# DEBUG: Action received - Selection Intensity: 0.5326, Budget to Spend: 0.3776
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 377.65
# DEBUG: Updated remaining budget: 622.35
# DEBUG: Base offspring: 100, Additional offspring: 37
# DEBUG: Total offspring to produce: 137
# DEBUG: num_select: 53, population size: 100
# DEBUG: Number of selected parents: 53
# DEBUG: Gametes per parent: 6
# DEBUG: New population size: 137
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 0.6977
# DEBUG: Action received - Selection Intensity: 0.3266, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 622.35
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 622.35
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 32, population size: 100
# DEBUG: Number of selected parents: 32
# DEBUG: Gametes per parent: 7
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.5841
# DEBUG: Action received - Selection Intensity: 0.2597, Budget to Spend: 0.2127
# DEBUG: Current remaining budget: 622.35
# DEBUG: Actual budget spent: 132.40
# DEBUG: Updated remaining budget: 489.95
# DEBUG: Base offspring: 100, Additional offspring: 13
# DEBUG: Total offspring to produce: 113
# DEBUG: num_select: 25, population size: 100
# DEBUG: Number of selected parents: 25
# DEBUG: Gametes per parent: 10
# DEBUG: New population size: 113
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.0211
# DEBUG: Action received - Selection Intensity: 0.9122, Budget to Spend: 0.9189
# DEBUG: Current remaining budget: 489.95
# DEBUG: Actual budget spent: 450.20
# DEBUG: Updated remaining budget: 39.75
# DEBUG: Base offspring: 100, Additional offspring: 45
# DEBUG: Total offspring to produce: 145
# DEBUG: num_select: 91, population size: 100
# DEBUG: Number of selected parents: 91
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 145
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.3025
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 39.75
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 39.75
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.5691
# DEBUG: Action received - Selection Intensity: 0.2533, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 39.75
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 39.75
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 25, population size: 100
# DEBUG: Number of selected parents: 25
# DEBUG: Gametes per parent: 8
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.5573
# DEBUG: Action received - Selection Intensity: 0.2727, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 39.75
# DEBUG: Actual budget spent: 39.75
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 3
# DEBUG: Total offspring to produce: 103
# DEBUG: num_select: 27, population size: 100
# DEBUG: Number of selected parents: 27
# ...
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 5.3846
# DEBUG: Action received - Selection Intensity: 0.0888, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 1000.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 100
# DEBUG: Total offspring to produce: 200
# DEBUG: num_select: 8, population size: 100
# DEBUG: Number of selected parents: 8
# DEBUG: Gametes per parent: 50
# DEBUG: New population size: 200
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.2862
# DEBUG: Action received - Selection Intensity: 0.1933, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 19, population size: 100
# DEBUG: Number of selected parents: 19
# DEBUG: Gametes per parent: 11
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.4469
# DEBUG: Action received - Selection Intensity: 0.9890, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 98, population size: 100
# DEBUG: Number of selected parents: 98
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.6799
# DEBUG: Action received - Selection Intensity: 0.5818, Budget to Spend: 0.1276
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 58, population size: 100
# DEBUG: Number of selected parents: 58
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.0965
# DEBUG: Action received - Selection Intensity: 0.3854, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 38, population size: 100
# DEBUG: Number of selected parents: 38
# DEBUG: Gametes per parent: 6
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.2480
# DEBUG: Action received - Selection Intensity: 0.6140, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 61, population size: 100
# DEBUG: Number of selected parents: 61
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.6783
# DEBUG: Action received - Selection Intensity: 0.3460, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 34, population size: 100
# DEBUG: Number of selected parents: 34
# DEBUG: Gametes per parent: 6
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.9582
# DEBUG: Action received - Selection Intensity: 0.6137, Budget to Spend: 0.7560
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 61, population size: 100
# DEBUG: Number of selected parents: 61
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.6996
# DEBUG: Action received - Selection Intensity: 0.6127, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 61, population size: 100
# DEBUG: Number of selected parents: 61
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.9478
# DEBUG: Action received - Selection Intensity: 0.5788, Budget to Spend: 0.4463
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 57, population size: 100
# DEBUG: Number of selected parents: 57
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.7393
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.7719
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 771.90
# DEBUG: Updated remaining budget: 228.10
# DEBUG: Base offspring: 100, Additional offspring: 77
# DEBUG: Total offspring to produce: 177
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 354
# DEBUG: New population size: 177
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.9409
# DEBUG: Action received - Selection Intensity: 0.9798, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 228.10
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 228.10
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 97, population size: 100
# DEBUG: Number of selected parents: 97
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.0164
# DEBUG: Action received - Selection Intensity: 0.3423, Budget to Spend: 0.1291
# DEBUG: Current remaining budget: 228.10
# DEBUG: Actual budget spent: 29.46
# DEBUG: Updated remaining budget: 198.64
# DEBUG: Base offspring: 100, Additional offspring: 2
# DEBUG: Total offspring to produce: 102
# DEBUG: num_select: 34, population size: 100
# DEBUG: Number of selected parents: 34
# DEBUG: Gametes per parent: 6
# DEBUG: New population size: 102
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.0629
# DEBUG: Action received - Selection Intensity: 0.6965, Budget to Spend: 0.9071
# DEBUG: Current remaining budget: 198.64
# DEBUG: Actual budget spent: 180.20
# DEBUG: Updated remaining budget: 18.44
# DEBUG: Base offspring: 100, Additional offspring: 18
# DEBUG: Total offspring to produce: 118
# DEBUG: num_select: 69, population size: 100
# DEBUG: Number of selected parents: 69
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 118
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.2273
# DEBUG: Action received - Selection Intensity: 0.5161, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 18.44
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 18.44
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 51, population size: 100
# DEBUG: Number of selected parents: 51
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.5909
# DEBUG: Action received - Selection Intensity: 0.1538, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 18.44
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 18.44
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 15, population size: 100
# DEBUG: Number of selected parents: 15
# DEBUG: Gametes per parent: 14
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.0989
# DEBUG: Action received - Selection Intensity: 0.3430, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 18.44
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 18.44
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 34, population size: 100
# DEBUG: Number of selected parents: 34
# DEBUG: Gametes per parent: 6
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.5414
# DEBUG: Action received - Selection Intensity: 0.9900, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 18.44
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 18.44
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 99, population size: 100
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.4796
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 18.44
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 18.44
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.1133
# DEBUG: Action received - Selection Intensity: 0.9900, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 18.44
# DEBUG: Actual budget spent: 18.44
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 1
# DEBUG: Total offspring to produce: 101
# DEBUG: num_select: 99, population size: 100
# DEBUG: Number of selected parents: 99
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 101
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 4.1133
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 1000.00
# DEBUG: Actual budget spent: 1000.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 100
# DEBUG: Total offspring to produce: 200
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 400
# DEBUG: New population size: 200
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.7159
# DEBUG: Action received - Selection Intensity: 0.7639, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 76, population size: 100
# DEBUG: Number of selected parents: 76
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 1.7519
# DEBUG: Action received - Selection Intensity: 0.3186, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 31, population size: 100
# DEBUG: Number of selected parents: 31
# DEBUG: Gametes per parent: 7
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.1062
# DEBUG: Action received - Selection Intensity: 0.2809, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 28, population size: 100
# DEBUG: Number of selected parents: 28
# DEBUG: Gametes per parent: 8
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.7228
# DEBUG: Action received - Selection Intensity: 0.6081, Budget to Spend: 0.1346
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 60, population size: 100
# DEBUG: Number of selected parents: 60
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 2.8133
# DEBUG: Action received - Selection Intensity: 0.0837, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 8, population size: 100
# DEBUG: Number of selected parents: 8
# DEBUG: Gametes per parent: 25
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.2865
# DEBUG: Action received - Selection Intensity: 0.5225, Budget to Spend: 0.6762
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 52, population size: 100
# DEBUG: Number of selected parents: 52
# DEBUG: Gametes per parent: 4
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.7343
# DEBUG: Action received - Selection Intensity: 0.7620, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 76, population size: 100
# DEBUG: Number of selected parents: 76
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.7197
# DEBUG: Action received - Selection Intensity: 0.0100, Budget to Spend: 1.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 1, population size: 100
# DEBUG: Number of selected parents: 1
# DEBUG: Gametes per parent: 200
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.8935
# DEBUG: Action received - Selection Intensity: 0.8314, Budget to Spend: 0.0000
# DEBUG: Current remaining budget: 0.00
# DEBUG: Actual budget spent: 0.00
# DEBUG: Updated remaining budget: 0.00
# DEBUG: Base offspring: 100, Additional offspring: 0
# DEBUG: Total offspring to produce: 100
# DEBUG: num_select: 83, population size: 100
# DEBUG: Number of selected parents: 83
# DEBUG: Gametes per parent: 3
# DEBUG: New population size: 100
# DEBUG: Final population size after selection: 100
# DEBUG: Reward: 3.9515
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 31.4         |
# | time/                   |              |
# |    fps                  | 348          |
# |    iterations           | 5            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0078779515 |
# |    clip_fraction        | 0.0414       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.861        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.62         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00506     |
# |    std                  | 0.919        |
# |    value_loss           | 9.67         |
# ------------------------------------------

# %%
max_generations= 10
total_timesteps = max_generations*5000
config = SimulationConfig(n_markers=100, starting_parents=200,pop_size=100,sparse_reward=False,seed=22)
SP = SimParams(config)

env = SelectionIntensityEnvironment(SP, config, max_generations=max_generations)
best_action, best_mean_max_phenotype, baseline_results = get_constant_action_baseline(env,)
print(best_action, best_mean_max_phenotype)

# %%
model = PPO("MultiInputPolicy", env, device='cuda', verbose=1, tensorboard_log=tensorboard_log)
vis_callback = GeneralizedVisualizationCallback(log_freq=1000,     baseline_results=baseline_results, best_action=best_action)
# Train the model
model.learn(total_timesteps=total_timesteps, callback=vis_callback)
